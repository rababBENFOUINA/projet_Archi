# %%
# !pip install -U ultralytics
from ultralytics import YOLO

model = YOLO()

#model.train(data="data.yml" , epochs=25)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.2/663.2 kB 4.3 MB/s eta 0:00:00
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 102MB/s]

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
# 'bac + 3 (1).pdf'	       deug_licence_merged.pdf
# 'bac + 3.pdf'		       deug.pdf
# 'bac + eleve_de_notes.pdf'     Document.pdf.docx
#  bac.pdf		       dossier.zip
# 'bascule JK.gsheet'	       ensemble_Learning_Grid
#  Capture10.PNG		      'Formulaire de candidature (File responses)'
#  Capture10.PNG.gdoc	      'Formulaire de candidature.gform'
# 'Capture1 (1).PNG'	      'Formulaire de candidature (réponses).gsheet'
#  Capture1.PNG		       freedomtech.zip
#  Capture1.PNG.gdoc	      'licence (1).pdf'
#  Capture2.PNG		      'licence (2).pdf'
#  Capture2.PNG.gdoc	      'licence (3).pdf'
# 'Capture3 (1).PNG.gdoc'        licence.pdf
#  Capture3.PNG		      'Logistic_Regression and SVM'
#  Capture3.PNG.gdoc	       logo.pdf
#  Capture4.PNG		       mobile
#  Capture5.PNG		      'My Drive'
#  Capture5.PNG.gdoc	      '#PFE'
# 'Capture6 (1).PNG.gdoc'       'presentation_soutenance (1).pdf'
#  Capture6.PNG		      'presentation_soutenance (2).pdf'
# ...

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !unzip /content/gdrive/MyDrive/data.zip
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   inflating: data/train/labels/hard_hat_workers4511_png.rf.8b23037a1fb2acdb445c500f9985bd70.txt
#   inflating: data/train/labels/hard_hat_workers4511_png.rf.cb41ea91c64ea66d18a3983bbff4d49d.txt
#   inflating: data/train/labels/hard_hat_workers4511_png.rf.d74bc8a5155e9a74325ab416f425df97.txt
#   inflating: data/train/labels/hard_hat_workers4512_png.rf.0e04e6296b12972f3207be05074ab389.txt
#   inflating: data/train/labels/hard_hat_workers4512_png.rf.332116b935055d2c251c0ddf66069fd0.txt
#   inflating: data/train/labels/hard_hat_workers4512_png.rf.8081221f5de59575db9a5c131193d4a0.txt
#   inflating: data/train/labels/hard_hat_workers4513_png.rf.2ed1081b221ba25c353b6a36736ca09c.txt
#   inflating: data/train/labels/hard_hat_workers4513_png.rf.780434104d29c1750c2ceb14c2390d21.txt
#   inflating: data/train/labels/hard_hat_workers4513_png.rf.e53ffdafaaf2fea8dd7ab1b2ae95fe86.txt
# ...

# %%
model.train(data="/content/data.yml" , epochs=80)
# Out:
# Ultralytics YOLOv8.0.231 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
#from ultralytics import YOLO

# !yolo task=detect mode=val model="D:\tst2\runs\detect\train\weights\best.pt" data=data.yml
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 8
#       6 import torch
#       7 import yaml
# ----> 8 from yolov5 import detect  # Assurez-vous d'avoir correctement installé yolov5 et ses dépendances
#      10 # Chargement des paramètres
#      11 task = 'detect'
#
# File ~\AppData\Roaming\Python\Python311\site-packages\yolov5\detect.py:43
#      41 if str(ROOT) not in sys.path:
#      42     sys.path.append(str(ROOT))  # add ROOT to PATH
# ---> 43 ROOT = Path(os.path.relpath(ROOT, Path.cwd()))  # relative
#      45 from yolov5.models.common import DetectMultiBackend
#      46 from yolov5.utils.dataloaders import IMG_FORMATS, VID_FORMATS, LoadImages, LoadScreenshots, LoadStreams
#
# File <frozen ntpath>:766, in relpath(path, start)
#
# ValueError: path is on mount 'C:', start on mount 'd:'

# %%
# !yolo task=detect mode=predict model="D:\tst2\runs\detect\train\weights\best.pt" conf=0.25 source=0
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 4
#       2 from pathlib import Path
#       3 import torch
# ----> 4 from yolov5 import detect  # Assurez-vous d'avoir correctement installé yolov5 et ses dépendances
#       6 # Chargement des paramètres
#       7 task = 'detect'
#
# File ~\AppData\Roaming\Python\Python311\site-packages\yolov5\detect.py:43
#      41 if str(ROOT) not in sys.path:
#      42     sys.path.append(str(ROOT))  # add ROOT to PATH
# ---> 43 ROOT = Path(os.path.relpath(ROOT, Path.cwd()))  # relative
#      45 from yolov5.models.common import DetectMultiBackend
#      46 from yolov5.utils.dataloaders import IMG_FORMATS, VID_FORMATS, LoadImages, LoadScreenshots, LoadStreams
#
# File <frozen ntpath>:766, in relpath(path, start)
#
# ValueError: path is on mount 'C:', start on mount 'd:'

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# []
